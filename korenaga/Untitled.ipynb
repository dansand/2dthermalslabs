# %%
# %pylab inline
import numpy as np
import os
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ls -lt results/T/2/Base/files/ | head -3
# Out:
# total 1032
# -rw-rw-r-- 1 ubuntu ubuntu 3032 Jun  9 02:32 norm_surface_sr_Base_4300.npy
# -rw-rw-r-- 1 ubuntu ubuntu 5984 Jun  9 02:32 velsurface_Base_4300.npy
# ls: write error

# %%
# !wc -l results/T/2/Base/results_modelT_2_Base.dat
# Out:
# 415 results/T/2/Base/results_modelT_2_Base.dat

# %%
sr = np.load('results/T/2/Base/files/norm_surface_sr_Base_4000.npy')
vel = np.load('results/T/2/Base/files/velsurface_Base_4000.npy')

# %%
fig, axes = plt.subplots(figsize=(8,2))
axes.plot(sr, color='g')
axes.plot(vel)
axes.set_ylim(-300, 300)
# Out:
# (-300, 300)

# %%
T2 = np.genfromtxt("results/T/3/Base/results_modelT_3_Base.dat", skip_header=0, skip_footer=1)

# %%
T2.shape
# Out:
# (69, 17)

# %%
fig, axes = plt.subplots(figsize=(4,4))
plt.plot(T2[:,0], T2[:,4], c='y',label="Avg. Temp")
plt.plot(T2[:,0], T2[:,5]/T2[:,-4], c='b',label="Avg. Temp. mantle")
plt.plot(T2[:,0], T2[:,6], c='r',label="Temp. max")
#axes.set_ylim(-300, 300)
axes.legend(loc=4)

# %%
T2[:,6].max(), T2[:,6].min()
# Out:
# (1.0917951667100001, 1.02069527243)

# %%
fig, axes = plt.subplots(figsize=(4,4))
plt.plot(T2[:,0], T2[:,5]/T2[:,-4], c='b',label="Avg. Temp. mantle")
plt.plot(T2[:,0], T2[:,-4], c='r',label="Avg. Area. mantle")
plt.plot(T2[:,0], T2[:,-3]/T2[:,-4], c='g',label="Avg. Visc. mantle")
#plt.plot(T2[:,0], T2[:,-2], c='k',label="Avg. Visc. diss mantle")


#axes.set_ylim(-300, 300)
#axes.legend(loc=4)

# %%
fig, axes = plt.subplots(figsize=(8,2))
plt.plot(T2[:,0], T2[:,-1], c='b',label="Plateness")
axes.legend()

# %%
fig, axes = plt.subplots(figsize=(8,2))
plt.plot(T2[:,0], T2[:,3], c='b',label="Nusselt surface")
axes.legend()

# %%
fig, axes = plt.subplots(figsize=(8,2))
plt.plot(T2[:,0], T2[:,7], c='r',label="Rms vel.")
plt.plot(T2[:,0], T2[:,8], c='b',label="Rms vel. surf")
axes.legend()
