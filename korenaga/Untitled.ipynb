# %%
# %pylab inline
import numpy as np
import os
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['axes']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
ls -lt results/T/2/Base/files/ | head -3
# Out:
# total 876
# -rw-rw-r-- 1 ubuntu ubuntu 3032 Jun  9 00:17 norm_surface_sr_Base_3650.npy
# -rw-rw-r-- 1 ubuntu ubuntu 5984 Jun  9 00:17 velsurface_Base_3650.npy

# %%
# !wc -l results/T/2/Base/results_modelT_2_Base.dat
# Out:
# 370 results/T/2/Base/results_modelT_2_Base.dat

# %%
sr = np.load('results/T/2/Base/files/norm_surface_sr_Base_3650.npy')
vel = np.load('results/T/2/Base/files/velsurface_Base_3650.npy')

# %%
fig, axes = plt.subplots(figsize=(16,4))
axes.plot(sr, color='g')
axes.plot(vel)
axes.set_ylim(-300, 300)
# Out:
# (-300, 300)

# %%
T2 = np.genfromtxt("results/T/2/Base/results_modelT_2_Base.dat", skip_header=0, skip_footer=1)

# %%
T2.shape
# Out:
# (374, 17)

# %%
fig, axes = plt.subplots(figsize=(4,4))
plt.plot(T2[:,0], T2[:,4], c='y',label="Avg. Temp")
plt.plot(T2[:,0], T2[:,5]/T2[:,-4], c='b',label="Avg. Temp. mantle")
plt.plot(T2[:,0], T2[:,6], c='r',label="Temp. max")
#axes.set_ylim(-300, 300)
axes.legend(loc=4)

# %%
T2[:,6].max(), T2[:,6].min()
# Out:
# (1.02069527243, 1.02069527243)
